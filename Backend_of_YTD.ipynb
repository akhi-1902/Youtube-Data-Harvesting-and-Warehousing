# %%
from googleapiclient.discovery import build

def youtube_data_api():
    api_key = 'AIzaSyCXVTkjqafkgoG4UJ94w4-5fmNdJ3oBriA'
    youtube = build("youtube", "v3", developerKey=api_key)
    channel_id = 'UCckHqySbfy5FcPP6MD_S-Yg'
    return youtube, channel_id

def get_channel_data(youtube, channel_id):
    request = youtube.channels().list(
        part="snippet,contentDetails,statistics,id",
        id=channel_id,
    )
    response = request.execute()
    return response

youtube, channel_id = youtube_data_api()
channel_data = get_channel_data(youtube, channel_id)

if isinstance(channel_data, dict):  # Check if the output is a dictionary
    for item in channel_data.get("items", []):
        print("ID:", item.get("id"))
        print("Snippet:", item.get("snippet"))
        print("ContentDetails:", item.get("contentDetails"))
        print("Statistics:", item.get("statistics"))
        print("----------")
# Out:
# ID: UCckHqySbfy5FcPP6MD_S-Yg
# ...

# %%
youtube, channel_id = youtube_data_api()
channel_data = get_channel_data(youtube, channel_id)

# %%
def get_channel_videos(youtube, channel_id):
    videos = []
    request = youtube.search().list(
        part='id,snippet',
        channelId=channel_id,
        maxResults=10
    )
    response = request.execute()

    for item in response.get("items", []):
        video_id = item.get("id", {}).get("videoId")
        video_request = youtube.videos().list(
            part="snippet,statistics,contentDetails",
            id=video_id
        )
        video_response = video_request.execute()
        video_data = video_response.get("items", [{}])[0]  # Take the first item

        details = {
            'Video_Id': video_id,
            'Video_Name': video_data.get("snippet", {}).get('title', ''),
            'Video_Description': video_data.get("snippet", {}).get('description', ''),
            'Tags': video_data['snippet'].get('tags', []),
            'PublishedAt': video_data['snippet'].get('publishedAt', ''),
            'View_Count': int(video_data['statistics'].get('viewCount', 0)),
            'Like_Count': int(video_data['statistics'].get('likeCount', 0)),
            'Dislike_Count': int(video_data['statistics'].get('dislikeCount', 0)),
            'Favorite_Count': int(video_data['statistics'].get('favoriteCount', 0)),
            'Comment_Count': int(video_data['statistics'].get('commentCount', 0)),
            'Duration': video_data['contentDetails'].get('duration', ''),
            'Thumbnail': video_data['snippet'].get('thumbnails', {}).get('default', {}).get('url', ''),
            'Caption_Status': video_data['snippet'].get('localized', {}).get('localized', 'Not Available'),
            'Comments': {}
                }


        videos.append(details)

    return videos

youtube, channel_id = youtube_data_api()
all_video_details = get_channel_videos(youtube, channel_id)

for video_data in all_video_details:
  print("Video Name:", video_data['Video_Name'])
  print("Video Description:", video_data['Video_Description'])
  print("Published At:", video_data['PublishedAt'])
  print("View Count:", video_data['View_Count'])
  print("Like Count:", video_data['Like_Count'])
  print("Dislike Count:", video_data['Dislike_Count'])
  print("Comment Count:", video_data['Comment_Count'])
  print("Duration:", video_data['Duration'])
  print("Thumbnail:", video_data['Thumbnail'])
# Out:
# Video Name: When PM Narendra Modi stopped car to meet 4-year-old girl
# Video Description: Prime Minister Narendra Modi surprised residents of diamond city Surat when he stopped his high security cavalcade to meet a 4-year-old girl who walked towards his SUV. On noticing the girl, the Special Protection Group (SPG) guard tried to stop her but Modi instructed to bring her to him.
#
# Subscribe to Times Of India's Youtube channel here: http://goo.gl/WgIatu
#
# Also Subscribe to Bombay Times Youtube Channel here: http://goo.gl/AdXcgU
#
# Social Media Links:
# Facebook : https://www.facebook.com/TimesofIndia
# Twitter : https://twitter.com/timesofindia
# Google + : https://plus.google.com/u/0/+timesindia/posts
# Published At: 2017-04-17T18:19:28Z
# View Count: 4426340
# Like Count: 59716
# Dislike Count: 0
# Comment Count: 0
# Duration: PT28S
# Thumbnail: https://i.ytimg.com/vi/1TM2We659FI/default.jpg
# ...
